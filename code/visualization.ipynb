# %%
import pandas as pd
data = pd.read_csv("../data/all_data.csv")
data.head()
# Out:
#    pID           Name Pos  Age Team  Game  GS    MP   FG  FGA  \
# 0    0    Jeff Adrien   F   25  HOU     8   0    63    7   16
# 1    0    Jeff Adrien   F   27  TOT    53  12   961  143  275
# 2    0    Jeff Adrien   F   28  MIN    17   0   215   19   44
# 3    0    Jeff Adrien   F   26  CHA    52   5   713   72  168
# 4    1  Arron Afflalo   F   27  ORL    64  64  2307  397  905
#
#          ...         WS/48  OBPM  DBPM  BPM  VORP     Salary        EFF  \
# 0        ...         0.106  -5.4  -2.3 -7.7  -0.1   916099.0   3.750000
# 1        ...         0.134  -1.4   0.3 -1.1   0.2        0.0   9.584906
# 2        ...         0.087  -2.7   0.5 -2.2   0.0        0.0   6.764706
# 3        ...         0.064  -3.0  -0.2 -3.3  -0.2   916099.0   6.096154
# 4        ...         0.042  -0.3  -2.0 -2.3  -0.2  7500000.0  12.921875
#
#     GmSc  salary_limit  last_year_salary
# 0   14.1      58044000               NaN
# 1  335.7      58679000          916099.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421 entries, 0 to 3420
# Data columns (total 55 columns):
# pID                 3421 non-null int64
# Name                3421 non-null object
# Pos                 3421 non-null object
# Age                 3421 non-null int64
# Team                3421 non-null object
# Game                3421 non-null int64
# GS                  3421 non-null int64
# MP                  3421 non-null int64
# FG                  3421 non-null int64
# FGA                 3421 non-null int64
# FG%                 3421 non-null float64
# 3P                  3421 non-null int64
# 3PA                 3421 non-null int64
# 3P%                 3421 non-null float64
# 2P                  3421 non-null int64
# 2PA                 3421 non-null int64
# 2P%                 3421 non-null float64
# eFG%                3421 non-null float64
# FT                  3421 non-null int64
# FTA                 3421 non-null int64
# ...

# %%
data_without_pid = data.drop(['pID','Name','Pos','Team'], axis=1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
data_without_pid.hist(bins=20, figsize=(20,15))
plt.show()

# %%
test = data[(data[['Salary']] != 0).all(axis=1)]
test2 = test[(test[['Pos']] != 'F-C').all(axis=1)]

# %%
sns.set(font_scale=1)
sns.catplot(x="Pos", y="Salary", kind="swarm", data=test2)

# %%
sns.boxplot(x="Pos", y="Salary", data=test2)

# %%
data_without_pid.cov()
# Out:
#                            Age          Game            GS            MP  \
# Age               1.819526e+01  4.740613e+00  3.046107e+00  1.463459e+02
# Game              4.740613e+00  6.143141e+02  4.199472e+02  1.809156e+04
# GS                3.046107e+00  4.199472e+02  7.961710e+02  1.988089e+04
# MP                1.463459e+02  1.809156e+04  1.988089e+04  7.059169e+05
# FG                7.790492e+00  2.990273e+03  3.745579e+03  1.274240e+05
# FGA               1.729442e+01  6.454922e+03  7.900442e+03  2.746210e+05
# FG%               3.340854e-03  7.822281e-01  6.644438e-01  2.245937e+01
# 3P                1.714507e+01  6.599577e+02  6.928212e+02  2.762326e+04
# 3PA               3.838673e+01  1.800604e+03  1.855334e+03  7.480982e+04
# 3P%               2.816868e-02  1.045913e+00  7.401820e-01  3.863681e+01
# 2P               -9.354574e+00  2.330315e+03  3.052758e+03  9.980076e+04
# 2PA              -2.109231e+01  4.654318e+03  6.045108e+03  1.998112e+05
# ...

# %%
import numpy as np
corr = test.corr()
f, ax = plt.subplots(figsize=(100, 60))

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True


sns.set(font_scale=2.8)
sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.3f', mask=mask,
                 linewidths=.05)

# %%
# Scatter Plot
sns.set(font_scale=1)
plt.scatter(data['last_year_salary'], data['Salary'],
            alpha=0.4, edgecolors='c')

plt.xlabel('last_year_salary')
plt.ylabel('Salary')
#plt.title('Wine Sulphates - Alcohol Content',y=1.05)


# Joint Plot
jp = sns.jointplot(x='last_year_salary', y='Salary', data=data,
                   kind='reg', space=0, size=5, ratio=4)
# Out:
# /usr/local/lib/python3.6/site-packages/seaborn/axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
